# %%
from neuralintents import GenericAssistant
import matplotlib.pyplot as plt
import pandas as pd
import pandas_datareader as web
import mplfinance as mpf
import pickle
import sys
import datetime as dt
from pandas_datareader import data as pdr
import yfinance as yf
yf.pdr_override()

# %%
portfolio ={'AAPL':20,'TSLA':5,'GS':10}
with open('portfolio.pkl','wb') as f:
    pickle.dump(portfolio,f)

# %%
with open('portfolio.pkl','rb') as f:
    portfolio = pickle.load(f)
print(portfolio)
# Out:
# {'AAPL': 20, 'TSLA': 5, 'GS': 10}

# %%
def save_portfolio():
    with open('portfolio.pkl' ,'wb') as f:
        pickle. dump(portfolio, f)


def add_portfolio():
    ticker = input("Which stock do you want to add: ")
    amount = int(input("How many shares do you want to add: "))
    if ticker in portfolio.keys():
        portfolio[ticker]+=amount
        print("Added successfully")
    else:
        portfolio[ticker]=amount    
    save_portfolio()

def remove_portfolio():
    ticker = input("Which stock do you want to sell: " )
    amount = int(input ("How many shares do you want to sell: "))
    if ticker in portfolio.keys():
        if amount <= portfolio[ticker]:
            portfolio[ticker] -= amount
            save_portfolio()
            print("Sold")
        else:
            print("Ypu don't have enought shares")
    else:
        print(f"You don't own any shares of {ticker}")

def show_portfolio():
    print("Your portfolio: ")
    for ticker in portfolio.keys():
        print(f"YOu own {portfolio[ticker]} shares of {ticker}")

# %%
def portfolio_worth():
    sum = 0
    for ticker in portfolio.keys():

        print(ticker)
        data = pdr.get_data_yahoo(ticker)
        price = data['Close'].iloc[-1]
        sum += price
    print(f"Your portfolio is worth {sum} USD")

# %%
def portfolio_gains():
    starting_date = input("Enter a date of comparison (YYYY-MM-DD): ")
    sum_now=0
    sum_then=0
    try:
        for ticker in portfolio.keys():
            data = pdr.get_data_yahoo(ticker)
            price_now = data['Close'].iloc[-1]
            price_then = data.loc[data.index == starting_date]['Close'].values[0]
            sum_now += price_now
            sum_then += price_then

        print(f"Relative Gains: {((sum_now-sum_then)/sum_then)*100}%")
        print(f"Absolute Gains: {sum_now-sum_then} USD")
    except IndexError:
        print("There was no trading on this day!")

# %%
def plot_chart():
    ticker = input("Choose a ticker symbol: ")
    starting_string = input("Choose a starting date (DD/MM/YYYY): ")
    plt.style.use('dark_background')
    start = dt.datetime.strptime(starting_string, "%d/%m/%Y")
    end = dt.datetime.now()
    data=pdr.get_data_yahoo(ticker,start, end)
    colors = mpf.make_marketcolors(up='#00ff00', down='#ff0000', wick = ' inherit', edge ='inherit', volume = 'in')
    mpf_style = mpf.make_mpf_style(base_mpf_style='nightclouds', marketcolors=colors)
    mpf.plot(data,type='candle', style = mpf_style, volume = True)

def bye():
    print("Goodbye")
    sys.exit(0)

# %%
mappings = {
    'plot_chart':plot_chart,
    "add_portfolio":add_portfolio,
    'remove_portfolio':remove_portfolio,
    'show_portfolio':show_portfolio,
    'portfolio_worth':portfolio_worth,
    'portfolio_gains':portfolio_gains,
    'bye':bye
}

assistant = GenericAssistant('intents.json',mappings, "financial_assistant_model")
assistant.train_model()
assistant.save_model()
# Out:
# c:\Anaconda3\envs\Tensorflow\lib\site-packages\neuralintents\main.py:97: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)
# c:\Anaconda3\envs\Tensorflow\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/200
# 14/14 [==============================] - 1s 5ms/step - loss: 2.2226 - accuracy: 0.1618
# Epoch 2/200
# 14/14 [==============================] - 0s 5ms/step - loss: 2.0554 - accuracy: 0.1912
# Epoch 3/200
# 14/14 [==============================] - 0s 4ms/step - loss: 1.9459 - accuracy: 0.3088
# Epoch 4/200
# 14/14 [==============================] - 0s 4ms/step - loss: 1.7835 - accuracy: 0.3676
# Epoch 5/200
# 14/14 [==============================] - 0s 4ms/step - loss: 1.5504 - accuracy: 0.4412
# Epoch 6/200
# 14/14 [==============================] - 0s 4ms/step - loss: 1.5178 - accuracy: 0.4412
# Epoch 7/200
# 14/14 [==============================] - 0s 5ms/step - loss: 1.2478 - accuracy: 0.4706
# Epoch 8/200
# 14/14 [==============================] - 0s 5ms/step - loss: 1.0888 - accuracy: 0.6176
# Epoch 9/200
# 14/14 [==============================] - 0s 6ms/step - loss: 1.0567 - accuracy: 0.6324
# Epoch 10/200
# 14/14 [==============================] - 0s 6ms/step - loss: 1.1046 - accuracy: 0.6324
# Epoch 11/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.8078 - accuracy: 0.7353
# Epoch 12/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.8258 - accuracy: 0.7353
# Epoch 13/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.7053 - accuracy: 0.7941
# Epoch 14/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.6240 - accuracy: 0.8676
# Epoch 15/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.6094 - accuracy: 0.8235
# Epoch 16/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.5417 - accuracy: 0.8529
# Epoch 17/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4982 - accuracy: 0.8676
# Epoch 18/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4403 - accuracy: 0.8824
# Epoch 19/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.3592 - accuracy: 0.9265
# Epoch 20/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3725 - accuracy: 0.8676
# Epoch 21/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.2723 - accuracy: 0.9412
# Epoch 22/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.4047 - accuracy: 0.9118
# Epoch 23/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3457 - accuracy: 0.8824
# Epoch 24/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3092 - accuracy: 0.9265
# Epoch 25/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3214 - accuracy: 0.8971
# Epoch 26/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2987 - accuracy: 0.9265
# Epoch 27/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2789 - accuracy: 0.9412
# Epoch 28/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2075 - accuracy: 0.9559
# Epoch 29/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1977 - accuracy: 0.9706
# Epoch 30/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2202 - accuracy: 0.9412
# Epoch 31/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1699 - accuracy: 0.9853
# Epoch 32/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1831 - accuracy: 0.9412
# Epoch 33/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1967 - accuracy: 0.9706
# Epoch 34/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1609 - accuracy: 0.9853
# Epoch 35/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1775 - accuracy: 0.9559
# Epoch 36/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1778 - accuracy: 0.9706
# Epoch 37/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1826 - accuracy: 0.9559
# Epoch 38/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0946 - accuracy: 0.9706
# Epoch 39/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1724 - accuracy: 0.9559
# Epoch 40/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0783 - accuracy: 1.0000
# Epoch 41/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1188 - accuracy: 0.9853
# Epoch 42/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1340 - accuracy: 0.9559
# Epoch 43/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1017 - accuracy: 0.9559
# Epoch 44/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1349 - accuracy: 0.9706
# Epoch 45/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0764 - accuracy: 1.0000
# Epoch 46/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0889 - accuracy: 0.9853
# Epoch 47/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0624 - accuracy: 0.9853
# Epoch 48/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0932 - accuracy: 0.9706
# Epoch 49/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.1176 - accuracy: 0.9706
# Epoch 50/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1078 - accuracy: 0.9853
# Epoch 51/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0740 - accuracy: 0.9853
# Epoch 52/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1582 - accuracy: 0.9559
# Epoch 53/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1072 - accuracy: 0.9559
# Epoch 54/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1362 - accuracy: 0.9706
# Epoch 55/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0909 - accuracy: 0.9853
# Epoch 56/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0635 - accuracy: 0.9853
# Epoch 57/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0843 - accuracy: 0.9853
# Epoch 58/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0955 - accuracy: 0.9559
# Epoch 59/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0778 - accuracy: 0.9853
# Epoch 60/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0559 - accuracy: 1.0000
# Epoch 61/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1047 - accuracy: 0.9706
# Epoch 62/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1097 - accuracy: 0.9706
# Epoch 63/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0652 - accuracy: 1.0000
# Epoch 64/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1161 - accuracy: 0.9706
# Epoch 65/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0435 - accuracy: 0.9853
# Epoch 66/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0817 - accuracy: 0.9706
# Epoch 67/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1132 - accuracy: 0.9559
# Epoch 68/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0517 - accuracy: 1.0000
# Epoch 69/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0507 - accuracy: 0.9853
# Epoch 70/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.1499 - accuracy: 0.9559
# Epoch 71/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 72/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0950 - accuracy: 0.9706
# Epoch 73/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0795 - accuracy: 0.9706
# Epoch 74/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0461 - accuracy: 1.0000
# Epoch 75/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0609 - accuracy: 0.9853
# Epoch 76/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0532 - accuracy: 0.9853
# Epoch 77/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0467 - accuracy: 1.0000
# Epoch 78/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0491 - accuracy: 1.0000
# Epoch 79/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1051 - accuracy: 0.9706
# Epoch 80/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0266 - accuracy: 1.0000
# Epoch 81/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0928 - accuracy: 0.9706
# Epoch 82/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0491 - accuracy: 1.0000
# Epoch 83/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0373 - accuracy: 0.9853
# Epoch 84/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 85/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 86/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0677 - accuracy: 0.9706
# Epoch 87/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0676 - accuracy: 0.9853
# Epoch 88/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0347 - accuracy: 1.0000
# Epoch 89/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 90/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0743 - accuracy: 0.9853
# Epoch 91/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0574 - accuracy: 0.9853
# Epoch 92/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1065 - accuracy: 0.9706
# Epoch 93/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0556 - accuracy: 0.9853
# Epoch 94/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0329 - accuracy: 1.0000
# Epoch 95/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0391 - accuracy: 1.0000
# Epoch 96/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 97/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 98/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 99/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0479 - accuracy: 0.9853
# Epoch 100/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0359 - accuracy: 1.0000
# Epoch 101/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0382 - accuracy: 1.0000
# Epoch 102/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 103/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0439 - accuracy: 1.0000
# Epoch 104/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0511 - accuracy: 0.9853
# Epoch 105/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0257 - accuracy: 0.9853
# Epoch 106/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0844 - accuracy: 0.9706
# Epoch 107/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0421 - accuracy: 1.0000
# Epoch 108/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0300 - accuracy: 0.9853
# Epoch 109/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 110/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 111/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0325 - accuracy: 0.9853
# Epoch 112/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0406 - accuracy: 0.9853
# Epoch 113/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0388 - accuracy: 1.0000
# Epoch 114/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0260 - accuracy: 1.0000
# Epoch 115/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0505 - accuracy: 0.9853
# Epoch 116/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0480 - accuracy: 1.0000
# Epoch 117/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 118/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0296 - accuracy: 1.0000
# Epoch 119/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 120/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0356 - accuracy: 0.9853
# Epoch 121/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 122/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0377 - accuracy: 0.9853
# Epoch 123/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 124/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0450 - accuracy: 0.9853
# Epoch 125/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 126/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 127/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0420 - accuracy: 0.9853
# Epoch 128/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0414 - accuracy: 0.9853
# Epoch 129/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0310 - accuracy: 1.0000
# Epoch 130/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 131/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0422 - accuracy: 0.9706
# Epoch 132/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0266 - accuracy: 1.0000
# Epoch 133/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0519 - accuracy: 0.9559
# Epoch 134/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0534 - accuracy: 0.9853
# Epoch 135/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 136/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 137/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 138/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0399 - accuracy: 0.9853
# Epoch 139/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 140/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 141/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 142/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 143/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0294 - accuracy: 0.9853
# Epoch 144/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0594 - accuracy: 0.9706
# Epoch 145/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 146/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 147/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 148/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 149/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0283 - accuracy: 1.0000
# Epoch 150/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0327 - accuracy: 0.9853
# Epoch 151/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0214 - accuracy: 1.0000
# Epoch 152/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 153/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0363 - accuracy: 0.9853
# Epoch 154/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 155/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 156/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 157/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0188 - accuracy: 1.0000
# Epoch 158/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0711 - accuracy: 0.9853
# Epoch 159/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0262 - accuracy: 1.0000
# Epoch 160/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 161/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0384 - accuracy: 0.9706
# Epoch 162/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 163/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 164/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 165/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0441 - accuracy: 0.9853
# Epoch 166/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 167/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 168/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 169/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 170/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 171/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 172/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 173/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 174/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 175/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 176/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 177/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 178/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 179/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 180/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0414 - accuracy: 0.9853
# Epoch 181/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0179 - accuracy: 1.0000
# Epoch 182/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0232 - accuracy: 1.0000
# Epoch 183/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 184/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 185/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0374 - accuracy: 0.9853
# Epoch 186/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0566 - accuracy: 0.9706
# Epoch 187/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 188/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 189/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 190/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 1.0000
# Epoch 191/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 192/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 193/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0219 - accuracy: 0.9853
# Epoch 194/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 195/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 196/200
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0386 - accuracy: 0.9853
# Epoch 197/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 198/200
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 199/200
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 200/200
# 14/14 [==============================] - 0s 5ms/step - loss: 0.0152 - accuracy: 0.9853

# %%
while True:
    message = str(input(""))
    assistant.request(message)
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 3
#       1 while True:
#       2     message = str(input(""))
# ----> 3     assistant.request(message)
#
# File c:\Anaconda3\envs\Tensorflow\lib\site-packages\neuralintents\main.py:185, in GenericAssistant.request(self, message)
#     182 ints = self._predict_class(message)
#     184 if ints[0]['intent'] in self.intent_methods.keys():
# --> 185     self.intent_methods[ints[0]['intent']]()
#     186 else:
#     187     return self._get_response(ints, self.intents)
#
# Cell In[55], line 8, in plot_chart()
#       6 end = dt.datetime.now()
#       7 data=pdr.get_data_yahoo(ticker,start, end)
# ----> 8 colors = mpf.make_marketcolors(up='#00ff00', down='#ff0000', wick = ' inherit', edge ='inherit', volume = 'in')
#       9 mpf_style = mpf.make_mpf_style(base_mpf_style='nightclouds', marketcolors=colors)
#      10 mpf.plot(data,type='candle', style = mpf_style, volume = True)
#
# File c:\Anaconda3\envs\Tensorflow\lib\site-packages\mplfinance\_styles.py:346, in make_marketcolors(**kwargs)
#     344         else:
#     345             kwa = {kw:config[kw]}
# --> 346         c   = _check_and_set_mktcolor(candle,**kwa)
#     347         marketcolors.update([(kw,c)])
#     349 if config['hollow'] is not None:
#
# File c:\Anaconda3\envs\Tensorflow\lib\site-packages\mplfinance\_styles.py:334, in make_marketcolors.<locals>._check_and_set_mktcolor(candle, **kwarg)
#     332     if not _mpf_is_color_like(colors[updown]):
#     333         err = f'NOT is_color_like() for {key}[\'{updown}\'] = {colors[updown]}'
# --> 334         raise ValueError(err)
#     335 return colors
#
# ValueError: NOT is_color_like() for wick['up'] =  inherit
